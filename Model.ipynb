# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
print('Libraries Import Successful')
# Out:
# Libraries Import Successful

# %%
dress_sales=pd.read_excel('Dress Sales.xlsx')
attribute=pd.read_excel('Attribute DataSet.xlsx')

# %%
print('Size of Dress Sales Dataset :',dress_sales.shape)
print('Size of Attribute Dataset   :',attribute.shape)
# Out:
# Size of Dress Sales Dataset : (500, 24)
# Size of Attribute Dataset   : (500, 14)

# %%
dress_sales.head()
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0  1006032852       2114       2274                 2491                 2660
# 1  1212192089        151        275                  570                  750
# 2  1190380701          6          7                    7                    7
# 3   966005983       1005       1128                 1326                 1455
# 4   876339541        996       1175                 1304                 1396
#
#    2013-06-09 00:00:00  2013-08-09 00:00:00  2013-10-09 00:00:00  \
# 0                 2727                 2887                 2930
# 1                  813                 1066                 1164
# 2                    8                    8                    9
# 3                 1507                 1621                 1637
# 4                 1432                 1559                 1570
#
#   2013-12-09 00:00:00 14/9/2013  ... 24/9/2013 26/9/2013 28/9/2013 30/9/2013  \
# ...

# %%
attribute.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
#Function to print entire columns

def display_all(df):
    with pd.option_context("display.max_columns", 500):
        display(df)

# %%
display_all(dress_sales.head())
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0  1006032852       2114       2274                 2491                 2660
# 1  1212192089        151        275                  570                  750
# 2  1190380701          6          7                    7                    7
# 3   966005983       1005       1128                 1326                 1455
# 4   876339541        996       1175                 1304                 1396
#
#    2013-06-09 00:00:00  2013-08-09 00:00:00  2013-10-09 00:00:00  \
# 0                 2727                 2887                 2930
# 1                  813                 1066                 1164
# 2                    8                    8                    9
# 3                 1507                 1621                 1637
# 4                 1432                 1559                 1570
#
#   2013-12-09 00:00:00 14/9/2013 16/9/2013 18/9/2013 20/9/2013 22/9/2013  \
# ...

# %%
dress_sales.columns
# Out:
# Index([         'Dress_ID',         '29/8/2013',         '31/8/2013',
#        2013-02-09 00:00:00, 2013-04-09 00:00:00, 2013-06-09 00:00:00,
#        2013-08-09 00:00:00, 2013-10-09 00:00:00, 2013-12-09 00:00:00,
#                '14/9/2013',         '16/9/2013',         '18/9/2013',
#                '20/9/2013',         '22/9/2013',         '24/9/2013',
#                '26/9/2013',         '28/9/2013',         '30/9/2013',
#        2013-02-10 00:00:00, 2013-04-10 00:00:00, 2013-06-10 00:00:00,
#        2010-08-10 00:00:00, 2013-10-10 00:00:00, 2013-12-10 00:00:00],
#       dtype='object')

# %%
#We need to tranform names of columns to DateTime format
columns_to_change=dress_sales.drop(['Dress_ID'],axis=1).columns.values.tolist()
pd.to_datetime(pd.Series(columns_to_change))
# Out:
# 0    2013-08-29
# 1    2013-08-31
# 2    2013-02-09
# 3    2013-04-09
# 4    2013-06-09
# 5    2013-08-09
# 6    2013-10-09
# 7    2013-12-09
# 8    2013-09-14
# 9    2013-09-16
# 10   2013-09-18
# 11   2013-09-20
# 12   2013-09-22
# 13   2013-09-24
# 14   2013-09-26
# 15   2013-09-28
# 16   2013-09-30
# 17   2013-02-10
# 18   2013-04-10
# 19   2013-06-10
# 20   2010-08-10
# 21   2013-10-10
# 22   2013-12-10
# dtype: datetime64[ns]

# %%
dress_sales.columns=['Dress_ID','2013-08-29', '2013-08-31', '2013-02-09', '2013-04-09', '2013-06-09', '2013-08-09',
       '2013-10-09', '2013-12-09', '2013-09-14', '2013-09-16', '2013-09-18', '2013-09-20',
       '2013-09-22', '2013-09-24', '2013-09-26', '2013-09-28', '2013-09-30', '2013-02-10',
       '2013-04-10', '2013-06-10', '2010-08-10', '2013-10-10', '2013-12-10']

# %%
display_all(dress_sales.head())
# Out:
#      Dress_ID  2013-08-29  2013-08-31  2013-02-09  2013-04-09  2013-06-09  \
# 0  1006032852        2114        2274        2491        2660        2727
# 1  1212192089         151         275         570         750         813
# 2  1190380701           6           7           7           7           8
# 3   966005983        1005        1128        1326        1455        1507
# 4   876339541         996        1175        1304        1396        1432
#
#    2013-08-09  2013-10-09 2013-12-09 2013-09-14 2013-09-16 2013-09-18  \
# 0        2887        2930       3119       3204       3277       3321
# 1        1066        1164       1558       1756       1878       1985
# 2           8           9         10         10         10         10
# 3        1621        1637       1723       1746       1783       1796
# 4        1559        1570       1638       1655       1681       1743
#
#   2013-09-20 2013-09-22  2013-09-24  2013-09-26  2013-09-28  2013-09-30  \
# ...

# %%
dress_sales.columns
# Out:
# Index(['Dress_ID', '2013-08-29', '2013-08-31', '2013-02-09', '2013-04-09',
#        '2013-06-09', '2013-08-09', '2013-10-09', '2013-12-09', '2013-09-14',
#        '2013-09-16', '2013-09-18', '2013-09-20', '2013-09-22', '2013-09-24',
#        '2013-09-26', '2013-09-28', '2013-09-30', '2013-02-10', '2013-04-10',
#        '2013-06-10', '2010-08-10', '2013-10-10', '2013-12-10'],
#       dtype='object')

# %%
dress_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    500 non-null    int64
#  1   2013-08-29  500 non-null    int64
#  2   2013-08-31  500 non-null    int64
#  3   2013-02-09  500 non-null    int64
#  4   2013-04-09  500 non-null    int64
#  5   2013-06-09  500 non-null    int64
#  6   2013-08-09  500 non-null    int64
#  7   2013-10-09  500 non-null    int64
#  8   2013-12-09  500 non-null    object
#  9   2013-09-14  500 non-null    object
#  10  2013-09-16  500 non-null    object
#  11  2013-09-18  500 non-null    object
#  12  2013-09-20  500 non-null    object
#  13  2013-09-22  500 non-null    object
#  14  2013-09-24  500 non-null    int64
#  15  2013-09-26  263 non-null    float64
#  16  2013-09-28  500 non-null    int64
#  17  2013-09-30  227 non-null    float64
#  18  2013-02-10  225 non-null    float64
# ...

# %%
#select object datatype features
dress_sales_object=dress_sales.select_dtypes(include=['object']).columns.tolist()
dress_sales_object
# Out:
# ['2013-12-09',
#  '2013-09-14',
#  '2013-09-16',
#  '2013-09-18',
#  '2013-09-20',
#  '2013-09-22']

# %%
dress_sales['2013-12-09'].unique()
# Out:
# array([3119, 1558, 10, 1723, 1638, 18, 251, 117, 17, 13, 65, 90, 1906,
#        2934, 49, 45, 1898, 12, 381, 227, 1248, 233, 1671, 5, 22, 1762,
#        105, 497, 7156, 1456, 279, 1004, 1244, 2321, 1706, 1744, 66, 569,
#        557, 156, 2930, 640, 878, 240, 112, 5475, 24, 1210, 4, 209, 218,
#        59, 1474, 921, 328, 567, 585, 359, 30, 8, 68, 2025, 293, 670, 375,
#        25, 415, 83, 369, 40, 826, 2366, 6, 73, 137, 1412, 393, 382, 14,
#        232, 401, 325, 308, 722, 16, 119, 174, 2, 0, 302, 808, 407, 237,
#        649, 1311, 348, 1966, 531, 81, 3544, 164, 1335, 72, 414, 134, 452,
#        221, 450, 1029, 1235, 7, 91, 665, 307, 169, 442, 217, 3, 264, 578,
#        194, 339, 165, 64, 132, 635, 113, 43, 1271, 460, 451, 41, 111, 549,
#        455, 1886, 61, 176, 280, 201, 488, 226, 472, 42, 386, 365, 664,
#        576, 356, 957, 204, 21, 224, 115, 103, 850, 46, 281, 559, 767, 343,
#        461, 1842, 202, 122, 350, 742, 114, 140, 37, 178, 283, 124, 74,
# ...

# %%
#Seems the variables is wrongly classified as object data type .
#We will convert into Numerical , Object within data i.e 'Removed' will be converted to NaN

for i in dress_sales.columns:
    if dress_sales[i].dtype==object:
        dress_sales[i]=pd.to_numeric(dress_sales[i], errors='coerce')

# %%
#Checking for NaN Values
missing_df=pd.DataFrame()
missing_df['Columns']=dress_sales.isnull().sum().keys()
missing_df['Values']=dress_sales.isnull().sum().values.tolist()
missing_df[missing_df['Values']>0]
# Out:
#        Columns  Values
# 8   2013-12-09       1
# 9   2013-09-14       1
# 10  2013-09-16       1
# 11  2013-09-18       1
# 12  2013-09-20       1
# 13  2013-09-22       1
# 15  2013-09-26     237
# 17  2013-09-30     273
# 18  2013-02-10     275
# 19  2013-04-10     274
# 21  2010-08-10     271
# 22  2013-10-10     271

# %%
#Checking DataDistribution 
missing_data_columns=['2013-09-26','2013-09-30','2013-02-10','2013-04-10','2010-08-10','2013-10-10']

dress_sales[missing_data_columns].hist(bins=20,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000237F3822388>,
# ...
#       dtype=object)

# %%
#Since Data is Right skewed , we can fill missing values with median

def Fill_Missing_Median(df):
    for n,c in df.items():        
            df[n] = df[n].fillna(df[n].median())
            
Fill_Missing_Median(dress_sales)

# %%
display_all(dress_sales.head())
# Out:
#      Dress_ID  2013-08-29  2013-08-31  2013-02-09  2013-04-09  2013-06-09  \
# 0  1006032852        2114        2274        2491        2660        2727
# 1  1212192089         151         275         570         750         813
# 2  1190380701           6           7           7           7           8
# 3   966005983        1005        1128        1326        1455        1507
# 4   876339541         996        1175        1304        1396        1432
#
#    2013-08-09  2013-10-09  2013-12-09  2013-09-14  2013-09-16  2013-09-18  \
# 0        2887        2930      3119.0      3204.0      3277.0      3321.0
# 1        1066        1164      1558.0      1756.0      1878.0      1985.0
# 2           8           9        10.0        10.0        10.0        10.0
# 3        1621        1637      1723.0      1746.0      1783.0      1796.0
# 4        1559        1570      1638.0      1655.0      1681.0      1743.0
#
# ...

# %%
#Check for unique values in data
print('Unique Values in Dress_ID : ',dress_sales['Dress_ID'].nunique())

print('Total Values in Dress_ID  : ',len(dress_sales['Dress_ID']))
# Out:
# Unique Values in Dress_ID :  475
# Total Values in Dress_ID  :  500

# %%
#Since we have some duplicate values in Dress_ID , we can take average of sales for those IDs
dress_sales_byID=dress_sales.copy()
dress_sales_byID=dress_sales_byID.groupby('Dress_ID').mean() #Taking mean for duplicate Dress_ID
dress_sales_byID=dress_sales_byID.T #Taking transpose
display_all(dress_sales_byID.head())
# Out:
# Dress_ID    444282011   510519284   511503677   520233308   522776523   \
# 2013-08-29         0.0         0.0         0.0       524.0       432.0
# 2013-08-31         0.0         0.0         0.0       550.0       466.0
# 2013-02-09         0.0         0.0         0.0       594.0       491.0
# 2013-04-09        76.0       190.0       623.0       603.0       510.0
# 2013-06-09        76.0       192.0       630.0       608.0       513.0
#
# Dress_ID    531254082   532874347   535968075   537463111   541172235   \
# 2013-08-29       203.0         0.0      1224.0         0.0       531.0
# 2013-08-31       309.0         0.0      1232.0         0.0       561.0
# 2013-02-09       341.0         0.0      1265.0         0.0       707.0
# 2013-04-09       348.0       734.0      1268.0       321.0       736.0
# 2013-06-09       351.0       728.0      1279.0       321.0       742.0
#
# Dress_ID    547555172   549159213   549401113   549437715   550959163   \
# ...

# %%
dress_sales_byID.index
# Out:
# Index(['2013-08-29', '2013-08-31', '2013-02-09', '2013-04-09', '2013-06-09',
#        '2013-08-09', '2013-10-09', '2013-12-09', '2013-09-14', '2013-09-16',
#        '2013-09-18', '2013-09-20', '2013-09-22', '2013-09-24', '2013-09-26',
#        '2013-09-28', '2013-09-30', '2013-02-10', '2013-04-10', '2013-06-10',
#        '2010-08-10', '2013-10-10', '2013-12-10'],
#       dtype='object')

# %%
dress_sales_byID.columns
# Out:
# Int64Index([ 444282011,  510519284,  511503677,  520233308,  522776523,
#              531254082,  532874347,  535968075,  537463111,  541172235,
#             ...
#             1219677488, 1220707172, 1223469038, 1225512606, 1235426503,
#             1246749980, 1246945687, 1249825438, 1250787559, 1253973206],
#            dtype='int64', name='Dress_ID', length=475)

# %%
#Analysing data for Sales of different Dress_IDs
display_all(dress_sales_byID.describe())
# Out:
# Dress_ID  444282011   510519284   511503677   520233308   522776523   \
# count      23.000000   23.000000   23.000000   23.000000   23.000000
# mean       75.304348  140.739130  528.217391  495.217391  424.478261
# std        30.781392   85.752401  211.270390  273.175760  227.642637
# min         0.000000    0.000000    0.000000   54.000000   54.000000
# 25%        79.000000   58.500000  567.000000  293.000000  247.000000
# 50%        82.000000  195.000000  602.000000  615.000000  527.000000
# 75%        90.500000  210.000000  633.000000  658.500000  591.000000
# max       102.000000  218.000000  645.000000  818.000000  619.000000
#
# Dress_ID  531254082   532874347    535968075   537463111   541172235   \
# count      23.000000   23.000000    23.000000   23.000000   23.000000
# mean      279.826087  548.086957   978.086957  212.260870  546.347826
# std       140.524554  227.612492   559.638919  143.323923  301.830116
# ...

# %%
#Top 10 Dress_ID with Most sales
dress_sales_byID.mean().sort_values(ascending=False)[:10]
# Out:
# Dress_ID
# 629131530     6779.434783
# 735635595     3995.869565
# 1006032852    3303.434783
# 749031896     3275.913043
# 737538048     2517.043478
# 1212192089    2272.000000
# 957723897     2173.173913
# 661795386     2153.130435
# 1004212992    2106.086957
# 624314841     2086.869565
# dtype: float64

# %%
#Top 10 Dress_ID with Least sales
dress_sales_byID.mean().sort_values(ascending=True)[:10]
# Out:
# Dress_ID
# 907669618     0.173913
# 1124754999    0.826087
# 1139064593    0.869565
# 703395323     0.869565
# 898316315     0.869565
# 1108613896    1.000000
# 1199765487    1.000000
# 1190558632    1.000000
# 1091877430    1.304348
# 1250787559    1.739130
# dtype: float64

# %%
#Visualing few features
sns.boxplot(dress_sales['2013-08-31'])

# %%
#Visualising entire data distribution
dress_sales.drop(['Dress_ID'],axis=1).hist(figsize=(12,12));

# %% [markdown]
# Since,Data is Right Skewed,We can use log transformation to tranform the data

# %%
for feature in dress_sales.columns:
    if feature != 'Dress_ID':
        dress_sales[feature] = np.log1p(dress_sales[feature])

# %%
#After Transoforming Data
dress_sales.drop(['Dress_ID'],axis=1).hist(figsize=(12,12));

# %%
attribute.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
attribute.shape
# Out:
# (500, 14)

# %%
#Checking for NaN Values
missing_df=pd.DataFrame()
missing_df['Columns']=attribute.isnull().sum().keys()
missing_df['Values']=attribute.isnull().sum().values.tolist()
missing_df[missing_df['Values']>0]
# Out:
#          Columns  Values
# 2          Price       2
# 5         Season       2
# 6       NeckLine       3
# 7   SleeveLength       2
# 8      waiseline      87
# 9       Material     128
# 10    FabricType     266
# 11    Decoration     236
# 12  Pattern Type     109

# %%
#Heatmap for plotting missing values
plt.figure(figsize=(10,6))
sns.heatmap(attribute.isnull(),cbar=False,cmap='viridis')

# %%
attribute.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        500 non-null    int64
#  1   Style           500 non-null    object
#  2   Price           498 non-null    object
#  3   Rating          500 non-null    float64
#  4   Size            500 non-null    object
#  5   Season          498 non-null    object
#  6   NeckLine        497 non-null    object
#  7   SleeveLength    498 non-null    object
#  8   waiseline       413 non-null    object
#  9   Material        372 non-null    object
#  10  FabricType      234 non-null    object
#  11  Decoration      264 non-null    object
#  12  Pattern Type    391 non-null    object
#  13  Recommendation  500 non-null    int64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 54.8+ KB

# %%
#filling NaN with Most Frequent 
Columns_to_impute=['Price' ,'Season' ,'NeckLine' ,'SleeveLength' ,'waiseline', 
                   'Material' ,'FabricType' ,'Decoration' ,'Pattern Type']

from sklearn_pandas import CategoricalImputer
imputer = CategoricalImputer(missing_values='NaN',
    strategy='most_frequent')

for columns in Columns_to_impute:
    attribute[columns]=imputer.fit_transform(attribute[columns])

# %%
attribute['Price'].value_counts()
# Out:
# Average      254
# Low          129
# low           45
# Medium        30
# very-high     21
# high          15
# High           6
# Name: Price, dtype: int64

# %%
attribute['Size'].value_counts()
# Out:
# M        177
# free     173
# L         96
# S         37
# XL        15
# small      1
# s          1
# Name: Size, dtype: int64

# %%
#There are some duplicate categories,We will replace them
attribute['Price']=attribute['Price'].replace('low',"Low")
attribute['Price']=attribute['Price'].replace('high',"High")

attribute['Size']=attribute['Size'].replace('s',"S")
attribute['Size']=attribute['Size'].replace('small',"S")

# %%
#To check If Data is Balanced or Not
attribute['Recommendation'].value_counts()
# Out:
# 0    290
# 1    210
# Name: Recommendation, dtype: int64

# %% [markdown]
# #### Univariate analysis

# %%
plt.figure(figsize=(10,7))
sns.countplot(attribute['Price'])

# %%
plt.figure(figsize=(10,7))
sns.countplot(attribute['Style'])

# %%
plt.figure(figsize=(10,7))
sns.countplot(attribute['Size'])

# %%
plt.figure(figsize=(10,7))
sns.countplot(attribute['Season'])

# %%
plt.figure(figsize=(15,7))
sns.countplot(attribute['Pattern Type'])

# %%
plt.figure(figsize=(15,7))
sns.countplot(attribute['Rating'])

# %%
sns.boxplot(attribute['Recommendation'],attribute['Rating'])
plt.show()

# %% [markdown]
# #### Bivariate analysis

# %%
pd.crosstab(attribute['Price'],attribute['Size']).plot(kind='bar',stacked=True);
plt.title('Price - Size',fontsize=15,fontweight='bold')
plt.ylabel('Count',fontsize=10,fontweight='bold')
plt.xlabel('Price',fontsize=10,fontweight='bold')
plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold')
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
pd.crosstab(attribute['Price'],attribute['waiseline']).plot(kind='bar',stacked=True);
plt.title('Price - Waistline',fontsize=15,fontweight='bold')
plt.ylabel('Count',fontsize=10,fontweight='bold')
plt.xlabel('Price',fontsize=10,fontweight='bold')
plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold')
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
pd.crosstab(attribute['Price'],attribute['Recommendation']).plot(kind='bar',stacked=True)
plt.title('Price - Recommendation',fontsize=15,fontweight='bold')
plt.ylabel('Count',fontsize=10,fontweight='bold')
plt.xlabel('Price',fontsize=10,fontweight='bold')
plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold')
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
pd.crosstab(attribute['Size'],attribute['Recommendation']).plot(kind='bar',stacked=True)
plt.title('Size - Recommendation',fontsize=15,fontweight='bold')
plt.ylabel('Count',fontsize=10,fontweight='bold')
plt.xlabel('Size',fontsize=10,fontweight='bold')
plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold')
# Out:
# (array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200.]),
#  <a list of 9 Text major ticklabel objects>)

# %%
sns.catplot(x="Price", hue="Recommendation", col="Recommendation",data=attribute, kind="count",height=4, aspect=.7,  facecolor=(0, 0, 0, 0),
linewidth=5,edgecolor=sns.color_palette("dark", 5))

# %%
sns.catplot(x="Size", hue="Recommendation", col="Recommendation",data=attribute, kind="count",height=4, aspect=.7,  facecolor=(0, 0, 0, 0),
linewidth=5,edgecolor=sns.color_palette("dark", 5))

# %%
sns.catplot(x="Season", hue="Recommendation", col="Recommendation",data=attribute, kind="count",height=5, aspect=1.5,  facecolor=(0, 0, 0, 0),
linewidth=5,edgecolor=sns.color_palette("dark", 5))

# %%
# Target Variable
labels =attribute['Recommendation'].value_counts(sort = True).index
sizes = attribute['Recommendation'].value_counts(sort = True)

colors = ["whitesmoke","red"]
explode = (0.1,0)  # explode 1st slice
 
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=270,)

plt.title('Percent of Recommendation')
plt.show()

# %%
df_final=attribute.copy()

df_final.drop(['Rating','Recommendation','Dress_ID'],axis=1,inplace=True) #droping non_object datatype feature,we will 
                                                                 # add them up after converting objects to categories

#Change any columns of strings in a panda's dataframe to a column of categorical values. This applies the changes inplace
def Change_To_CategoricalValue(df):
    for n,c in df.items():
        if pd.api.types.is_object_dtype(c):
            df[n] = c.astype('category').cat.as_ordered()
            
Change_To_CategoricalValue(df_final)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Style         500 non-null    category
#  1   Price         500 non-null    category
#  2   Size          500 non-null    category
#  3   Season        500 non-null    category
#  4   NeckLine      500 non-null    category
#  5   SleeveLength  500 non-null    category
#  6   waiseline     500 non-null    category
#  7   Material      500 non-null    category
#  8   FabricType    500 non-null    category
#  9   Decoration    500 non-null    category
#  10  Pattern Type  500 non-null    category
# dtypes: category(11)
# memory usage: 11.8 KB

# %%
#Converting categorical features df to categorical codes And Dummies
def Change_To_Categoricalcodes(df):
    for n,c in df.items():
            df[n]=c.cat.codes
        
Change_To_Categoricalcodes(df_final)

df_final['Ratings']=attribute['Rating']
df_final['Target']=attribute['Recommendation']
df_final['Dress_ID']=attribute['Dress_ID']

# %%
#Mergin the two DataFrame
Sales_df = pd.merge(df_final ,dress_sales,on = 'Dress_ID')
display_all(Sales_df.head())
# Out:
#    Style  Price  Size  Season  NeckLine  SleeveLength  waiseline  Material  \
# 0      5      2     1       3         7            10          1         3
# 1      1      2     0       3         7             0          2         8
# 2     11      1     0       0         7             4          2        15
# 3      0      0     0       2         7             4          2        18
# 4      7      2     1       3         7             1          2         2
#
#    FabricType  Decoration  Pattern Type  Ratings  Target    Dress_ID  \
# 0           3          20             0      4.6       1  1006032852
# 1           3          20             0      0.0       0  1212192089
# 2           3          12            10      0.0       0  1190380701
# 3           3           8            10      4.6       1   966005983
# 4           3           3             2      4.5       0   876339541
#
#    2013-08-29  2013-08-31  2013-02-09  2013-04-09  2013-06-09  2013-08-09  \
# ...

# %%
from sklearn.model_selection import train_test_split
X = Sales_df.drop(['Target','Dress_ID'],axis=1)
y = Sales_df["Target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state =1)

# %%
print('The number of samples into the Train data is {}.'.format(X_train.shape[0]))
print('The number of samples into the test data is {}.'.format(X_test.shape[0]))
# Out:
# The number of samples into the Train data is 440.
# The number of samples into the test data is 110.

# %%
#Feature selection using Random Forest

from sklearn.ensemble import RandomForestClassifier
params={'random_state':0,'n_jobs':-1,'n_estimators':5000,'max_depth':8}

clf = RandomForestClassifier(**params)
clf = clf.fit(X, y)

# Plot features importances
imp = pd.Series(data=clf.feature_importances_, index=X.columns).sort_values(ascending=False)
plt.figure(figsize=(10,12))
plt.title("Feature importance")
ax = sns.barplot(y=imp.index, x=imp.values, palette="Blues_d", orient='h')

# %%
from sklearn.linear_model import LogisticRegression

logistic_model=LogisticRegression(C=1.0, class_weight=None, dual=False,
                                          fit_intercept=True,
                                          intercept_scaling=1, l1_ratio=None,
                                          max_iter=400, multi_class='auto',
                                          n_jobs=None, penalty='l2',
                                          random_state=None, solver='lbfgs',
                                          tol=0.0001, verbose=0,
                                          warm_start=False)
logistic_model.fit(X_train,y_train)

accuracy = logistic_model.score(X_test,y_test)
print("Logistic Regression accuracy is :",accuracy*100)
# Out:
# Logistic Regression accuracy is : 55.45454545454545

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV,cross_val_score
model=GradientBoostingClassifier()


model_parameters = { 
    'n_estimators' : [10,50,100,200,500],
    'max_depth' : [3,5,10,None],
    'min_samples_leaf' : [np.random.randint(1,10)] 
}

gscv_GBM=GridSearchCV(estimator=model,
                     param_grid=model_parameters,
                     cv=5,
                     verbose=1,
                     scoring='accuracy')

gscv_GBM.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  2.1min finished
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'max_depth': [3, 5, 10, None], 'min_samples_leaf': [2],
#                          'n_estimators': [10, 50, 100, 200, 500]},
#              scoring='accuracy', verbose=1)

# %%
print('The best parameter are -', gscv_GBM.best_params_)
# Out:
# The best parameter are - {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 500}

# %%
final_mod_GBM = GradientBoostingClassifier(**gscv_GBM.best_params_)
final_mod_GBM.fit(X_train, y_train)

from sklearn.metrics import classification_report
train_pred = final_mod_GBM.predict(X_train)
test_pred = final_mod_GBM.predict(X_test)

print('Classification report for test data is : \n',
      classification_report(y_test, test_pred))
# Out:
# Classification report for test data is :
#                precision    recall  f1-score   support
#
#            0       0.66      0.56      0.60        63
#            1       0.51      0.62      0.56        47
#
#     accuracy                           0.58       110
#    macro avg       0.58      0.59      0.58       110
# weighted avg       0.60      0.58      0.58       110

# %%
from xgboost import XGBClassifier
model = XGBClassifier()

model_parameters = { 
        'n_estimators':[10, 50, 100, 200, 500],
        'max_depth': [3, 5, 10],
        'min_samples_leaf': [np.random.randint(1,10)]
                  }


gscv = GridSearchCV(estimator=model, 
                    param_grid=model_parameters, 
                    cv=5, 
                    verbose=1, 
                    scoring='accuracy')

gscv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  1.3min finished
# GridSearchCV(cv=5, estimator=XGBClassifier(),
#              param_grid={'max_depth': [3, 5, 10], 'min_samples_leaf': [2],
#                          'n_estimators': [10, 50, 100, 200, 500]},
#              scoring='accuracy', verbose=1)

# %%
print('The best parameter are -', gscv.best_params_)
# Out:
# The best parameter are - {'n_estimators': 300, 'min_samples_leaf': 8, 'min_child_weight': 3, 'max_depth': 10, 'learning_rate': 0.15, 'booster': 'gbtree', 'base_score': 0.75}

# %%
final_mod_xgb = XGBClassifier(max_depth= 5, min_samples_leaf= 2, n_estimators= 500,learning_rate=0.1)

final_mod_xgb.fit(X_train, y_train)

from sklearn.metrics import classification_report
test_pred = final_mod_xgb.predict(X_test)

print('Classification report for test data is : \n',
      classification_report(y_test, test_pred))
# Out:
# Classification report for test data is :
#                precision    recall  f1-score   support
#
#            0       0.64      0.70      0.67        63
#            1       0.54      0.47      0.50        47
#
#     accuracy                           0.60       110
#    macro avg       0.59      0.58      0.58       110
# weighted avg       0.59      0.60      0.60       110

# %%
from sklearn.metrics import confusion_matrix
cm_lr = confusion_matrix(y_test,final_mod_xgb.predict(X_test))

# %% confusion matrix visualization
import seaborn as sns
f, ax = plt.subplots(figsize = (6,5))
sns.heatmap(cm_lr, annot = True, linewidths = 0.5, color = "red", fmt = ".0f", ax=ax)
plt.xlabel("y_predicted")
plt.ylabel("y_true")
plt.title("Confusion Matrix of Extreme Gradient Boosting")
plt.show()
